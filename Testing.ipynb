# %%
import pandas as pd

# %%
df= pd.read_csv('testing.csv', header=None, names=['ID','Name','Age'], index_col=0,usecols=['ID','Name'])

# %%
df.head()
# Out:
#            Name
# ID
# 1          Manu
# 2        Barath
# 3    Periyasamy
# 4   Kanakarajan
# 5      Balamani

# %%
df1=pd.read_csv('Testing_Csv.csv',sep='|',skiprows=2,header=None,names=['ID','Name','Age','DOB'],parse_dates=[3],dayfirst=True)
df1.head()
# Out:
#    ID    Name  Age         DOB
# 0   1    Manu   24  27-02-2002
# 1   2  Barath   25  29-02-2002

# %%
email_Ids=['manubarath33@gmail.com','barathmanu05@gmail.com']
df1['Email']=email_Ids

# %%
df1.head()
# Out:
#    ID    Name  Age         DOB                   Email
# 0   1    Manu   24  27-02-2002  manubarath33@gmail.com
# 1   2  Barath   25  29-02-2002  barathmanu05@gmail.com

# %%
LastName=['Kanakarajan','Balamani']

df1.insert(2,'LastName','LastName')

# %%
df1.head()
# Out:
#    ID    Name  LastName  Age         DOB                   Email
# 0   1    Manu  LastName   24  27-02-2002  manubarath33@gmail.com
# 1   2  Barath  LastName   25  29-02-2002  barathmanu05@gmail.com
